# %% [markdown]
# <a href="https://colab.research.google.com/github/kterra/idp-mba-jdados/blob/main/notebooks/P4_Introdu%C3%A7%C3%A3o_ao_Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Primeiros passos com Matplotlib

# %% [markdown]
# Saiba mais sobre a [história do matplotlib](http://www.aosabook.org/en/matplotlib.html).

# %% [markdown]
# ## Partes de uma figura no matplotlib
# Tutorais oficiais: https://matplotlib.org/stable/tutorials/index
#
# Veja a [documentação](https://matplotlib.org/stable/tutorials/introductory/usage.html#sphx-glr-tutorials-introductory-usage-py).

# %% [markdown]
# ![matplotlib_figure_axes_axis (4).png](data:image/png;base64,...)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4], "ro")
plt.show()

# %%
import numpy as np
x = np.arange(0,10, 0.1)
fig1, f1_axes = plt.subplots(ncols=2, nrows=2, figsize=(15,10))
fig1.suptitle("Minha primeira figura", size=30)

f1_axes[0, 0].plot(np.sin(x), label="sen(x)", color="purple")
f1_axes[0, 0].plot(np.cos(x), label="cos(x)", color="pink")
f1_axes[0, 0].set_title("Caixa 1")
f1_axes[0, 0].set_xlabel("Caixa 1 - Label X")
f1_axes[0, 0].set_ylabel("Caixa 1 - Label Y")
f1_axes[0, 0].legend()

f1_axes[0, 1].plot(np.cos(x))
f1_axes[0, 1].set_title("Caixa 2")

f1_axes[1, 0].plot(np.tan(x))
f1_axes[1, 0].set_title("Caixa 3")

f1_axes[1, 1].set_title("Caixa 4")
# Out:
# Text(0.5, 1.0, 'Caixa 4')

# %%
matplotlib.colors?
# Out:
# Object `matplotlib.colors` not found.

# %% [markdown]
# ### Para revisar o conteúdo da aula:

# %%
from IPython.display import YouTubeVideo
YouTubeVideo('iSpi3rKdoLQ')
